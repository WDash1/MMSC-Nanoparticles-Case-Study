# %%
import numpy as np
import pylab as pl
# %matplotlib inline

# %%
r = np.linspace(1, 100, 1000)

# %%
N0 = 1000
N  = N0 * np.exp(-0.02 * (r-50)**2)

# %%
pl.semilogy(r, N)

# %%
np.mean(N) * (r[1] - r[0])
# Out:
# 12.533141373155017
